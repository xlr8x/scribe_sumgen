# %%
# %pip install -r /Workspace/scribe_sumgen/requirements.txt

# %%
dbutils.library.restartPython()

# %%
# Run this to see your workspace path
dbutils.notebook.entry_point.getDbutils().notebook().getContext().notebookPath().get()

# %%
PROJECT_ROOT = "/Workspace/scribe_sumgen"

# %%
# ===== FIRST CELL - RUN THIS FIRST =====
import sys

PROJECT_ROOT = "/Workspace/scribe_sumgen"

if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

print(f"✅ Python path configured: {PROJECT_ROOT}")

# %%
# Second cell - test imports
from src.parsers.pdf_parser import ClinicalPDFParser

parser = ClinicalPDFParser()
print("✅ Import successful! Ready to go.")
